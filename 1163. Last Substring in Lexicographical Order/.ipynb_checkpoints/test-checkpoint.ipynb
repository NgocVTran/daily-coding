# %% [markdown]
# Given a string s, return the last substring of s in lexicographical order.
#
#
#
# Example 1:
#
# Input: "abab"
# Output: "bab"
# Explanation: The substrings are ["a", "ab", "aba", "abab", "b", "ba", "bab"]. The lexicographically maximum substring is "bab".
# Example 2:
#
# Input: "leetcode"
# Output: "tcode"
#
#
# Note:
#
# 1 <= s.length <= 4 * 10^5
# s contains only lowercase English letters.

# %%
# s = "abab"
# # Output: "bab"

# s = "leetcode"
# # Output: "tcode"

# s = "cacacb" # "cb"

s = "..."
# s = "...... 150002 more chars

# %%
max(s)
# Out:
# 'c'

# %%
# s[s.index(max(s)):]

# %%
compare = []

# %%
for ite,char in enumerate(s):
    if char == max(s):
        compare.append(s[ite:])

# %%
compare
# Out:
# ['cacacb', 'cacb', 'cb']

# %%
len(compare)
# Out:
# 3

# %%
sorted(compare, reverse=True)
# Out:
# ['cb', 'cacb', 'cacacb']

# %%
"cb" > "cacb"
# Out:
# True

# %%
max(compare)
# Out:
# 'cb'

# %% [markdown]
# ### solution

# %%
def lastSubstring(s):
    compare = []
    m = max(s)
    
    current_max = s[0]
    for ite,char in enumerate(s):
        if char == m:
            if s[ite:]>current_max:
                current_max = s[ite:]
    
    return current_max

# %%
# s = "abab" # "bab"
s = "leetcode" # "tcode"
# s = "cacacb" # "cb"
# s = "..."

# %%
lastSubstring(s)
# Out:
# 'tcode'
